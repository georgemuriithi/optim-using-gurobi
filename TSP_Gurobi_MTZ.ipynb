# %% [markdown]
# ### Problem description

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1. Importing packages

# %%
# !pip install gurobipy
# Out:
# Collecting gurobipy
#   Downloading gurobipy-9.5.0-cp37-cp37m-manylinux2014_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 5.4 MB/s
# Installing collected packages: gurobipy
# Successfully installed gurobipy-9.5.0

# %%
import gurobipy as gp
from gurobipy import GRB

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.spatial.distance import pdist, squareform
import numpy as np

# %% [markdown]
# ### 2. Loading dataset

# %%
# reading data and computing distance matrix
def prepare_tsp_data(filename):
    ct = pd.read_csv(filename)
    D = squareform(pdist(ct))
    return ct, D

# %%
# plotting cities and tours
def plot_tour(ct, tour=None, open_tour=False):
    plt.figure(figsize=(10,10))
    plt.scatter(ct.x, ct.y)
    if tour:
        for i, j in tour:
            x1 = ct.loc[i]['x']
            x2 = ct.loc[j]['x']
            y1 = ct.loc[i]['y']
            y2 = ct.loc[j]['y']
            plt.text(ct.loc[i]['x'], ct.loc[i]['y'], ct.loc[i]['id'])
            plt.text(ct.loc[j]['x'], ct.loc[j]['y'], ct.loc[j]['id'])
            x = [x1, x2]
            y = [y1, y2]
            if j == 0:
                if not open_tour:
                    plt.plot(x, y, 'r')
            else:
                plt.plot(x, y, 'black')

# %%
ct, D = prepare_tsp_data('usa35.csv')
plot_tour(ct)

# %% [markdown]
# ### 3. MTZ formulation

# %%
def solve_tsp(ct, D):
    try:
        N = ct.shape[0]

        # model
        tsp_model = gp.Model('tsp')

        # variables
        x, u = {}, {}
        for i in range(N):
            u[i] = tsp_model.addVar(lb=0, ub=N-1, vtype=GRB.CONTINUOUS, name=f'u{i}')
            for j in range(N):
                x[i,j] = tsp_model.addVar(vtype=GRB.BINARY, name=f'x{i,j}')
        
        # objective
        tsp_model.setObjective(gp.quicksum(x[i,j]*D[i,j] for j in range(N) for i in range(N)), 
                              GRB.MINIMIZE)
        
        # constraints
        # no self-connection
        for i in range(N):
            tsp_model.addConstr(x[i,i] == 0)

        # unique incoming edge
        for j in range(N):
            tsp_model.addConstr(gp.quicksum(x[i,j] for i in range(N)) == 1)

        # unique outgoing edge
        for i in range(N):
            tsp_model.addConstr(gp.quicksum(x[i,j] for j in range(N)) == 1)

        # preventing sub-tours
        for i in range(N):
            for j in range(N):
                if j != 0:
                    tsp_model.addConstr(u[j] >= u[i] + 1 - (2*N)*(1 - x[i,j]))
        
        # optimize model
        tsp_model.optimize()

        print('-----------------------------')
        print(f'Min. Dist = {tsp_model.objVal}')
        tour = [(i,j) for i in range(N) for j in range(N) if x[i,j].x == 1]
        plot_tour(ct, tour)
    except gp.GurobiError as e:
        print('Error code ' + str(e.errno) + ': ' + str(e))
        
solve_tsp(ct, D)
# Out:
# Restricted license - for non-production use only - expires 2023-10-25
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (linux64)
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
# Optimize a model with 1295 rows, 1260 columns and 5987 nonzeros
# Model fingerprint: 0x2da8c234
# Variable types: 35 continuous, 1225 integer (1225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [2e+02, 8e+03]
#   Bounds range     [1e+00, 3e+01]
#   RHS range        [1e+00, 7e+01]
# Presolve removed 69 rows and 36 columns
# Presolve time: 0.02s
# Presolved: 1226 rows, 1224 columns, 5814 nonzeros
# Variable types: 34 continuous, 1190 integer (1190 binary)
# Found heuristic solution: objective 94573.641349
#
# Root relaxation: objective 2.383162e+04, 111 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 23831.6235    0   60 94573.6413 23831.6235  74.8%     -    0s
# H    0     0                    31552.791686 23831.6235  24.5%     -    0s
#      0     0 26114.1949    0   65 31552.7917 26114.1949  17.2%     -    0s
#      0     0 26114.1949    0   63 31552.7917 26114.1949  17.2%     -    0s
#      0     0 26384.6919    0   67 31552.7917 26384.6919  16.4%     -    0s
#      0     0 26384.6919    0   67 31552.7917 26384.6919  16.4%     -    0s
#      0     0 26384.6919    0   67 31552.7917 26384.6919  16.4%     -    0s
# H    0     0                    30368.409260 26384.6919  13.1%     -    0s
#      0     0 26384.6919    0   67 30368.4093 26384.6919  13.1%     -    0s
#      0     0 26384.6919    0   44 30368.4093 26384.6919  13.1%     -    0s
#      0     0 26384.6919    0   44 30368.4093 26384.6919  13.1%     -    0s
#      0     0 26384.6919    0   44 30368.4093 26384.6919  13.1%     -    0s
# H    0     0                    29540.359361 26496.1198  10.3%     -    0s
#      0     0 26496.1198    0   60 29540.3594 26496.1198  10.3%     -    0s
#      0     0 26496.1198    0   58 29540.3594 26496.1198  10.3%     -    0s
#      0     0 26496.1198    0   58 29540.3594 26496.1198  10.3%     -    0s
#      0     0 26496.1198    0   60 29540.3594 26496.1198  10.3%     -    0s
#      0     0 26496.1198    0   60 29540.3594 26496.1198  10.3%     -    0s
#      0     0 26496.1198    0   64 29540.3594 26496.1198  10.3%     -    0s
#      0     0 26496.1198    0   64 29540.3594 26496.1198  10.3%     -    0s
#      0     0 26496.1198    0   58 29540.3594 26496.1198  10.3%     -    0s
#      0     0 26496.1198    0   58 29540.3594 26496.1198  10.3%     -    0s
# H    0     0                    27973.311604 26580.5306  4.98%     -    0s
#      0     0 26580.5306    0   60 27973.3116 26580.5306  4.98%     -    0s
#      0     0 26580.5306    0   64 27973.3116 26580.5306  4.98%     -    0s
#      0     0 26580.5306    0   64 27973.3116 26580.5306  4.98%     -    0s
#      0     0 26580.5306    0   44 27973.3116 26580.5306  4.98%     -    0s
#      0     0 26580.5306    0   64 27973.3116 26580.5306  4.98%     -    0s
#      0     0 26580.5306    0   68 27973.3116 26580.5306  4.98%     -    0s
#      0     0 26629.7781    0   66 27973.3116 26629.7781  4.80%     -    0s
#      0     0 26651.7932    0   64 27973.3116 26651.7932  4.72%     -    0s
#      0     0 26651.7932    0   64 27973.3116 26651.7932  4.72%     -    0s
#      0     0 26651.7932    0   64 27973.3116 26651.7932  4.72%     -    0s
#      0     0 26651.7932    0   64 27973.3116 26651.7932  4.72%     -    0s
#      0     0 26651.7932    0   40 27973.3116 26651.7932  4.72%     -    0s
#      0     2 26712.4949    0   40 27973.3116 26712.4949  4.51%     -    0s
# H  104    63                    27840.241732 26728.7975  3.99%  10.7    1s
# *  159    86              16    27812.055428 26740.8793  3.85%  10.3    1s
# H  789   208                    27567.635723 26901.0323  2.42%  11.2    1s
#
# Cutting planes:
#   Learned: 24
#   Gomory: 12
#   Cover: 12
#   Implied bound: 85
#   MIR: 40
#   Inf proof: 23
#   RLT: 9
#   Relax-and-lift: 52
#
# Explored 2199 nodes (28529 simplex iterations) in 2.73 seconds (1.41 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 8: 27567.6 27812.1 27840.2 ... 94573.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.756763572320e+04, best bound 2.756587925356e+04, gap 0.0064%
# -----------------------------
# Min. Dist = 27567.635723197694
